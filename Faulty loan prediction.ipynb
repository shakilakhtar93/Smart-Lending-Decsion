# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Admin\Downloads\loan_dataset.csv')
df
# Out:
#            Id   Income  Age  Experience Married/Single House_Ownership  \
# 0           1  1303834   23           3         single          rented
# 1           2  7574516   40          10         single          rented
# 2           3  3991815   66           4        married          rented
# 3           4  6256451   41           2         single          rented
# 4           5  5768871   47          11         single          rented
# ...       ...      ...  ...         ...            ...             ...
# 99995   99996  7283454   74           5        married          rented
# 99996   99997   170128   29          17         single          rented
# 99997   99998  1094592   79           0         single          rented
# 99998   99999  6384060   26          14         single           owned
# 99999  100000   207067   61          18         single          rented
#
#       Car_Ownership           Profession                 CITY           STATE  \
# ...

# %%
df.dtypes
# Out:
# Id                    int64
# Income                int64
# Age                   int64
# Experience            int64
# Married/Single       object
# House_Ownership      object
# Car_Ownership        object
# Profession           object
# CITY                 object
# STATE                object
# CURRENT_JOB_YRS       int64
# CURRENT_HOUSE_YRS     int64
# Risk_Flag             int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Id                   0
# Income               0
# Age                  0
# Experience           0
# Married/Single       0
# House_Ownership      0
# Car_Ownership        0
# Profession           0
# CITY                 0
# STATE                0
# CURRENT_JOB_YRS      0
# CURRENT_HOUSE_YRS    0
# Risk_Flag            0
# dtype: int64

# %%
df.describe()
# Out:
#                   Id        Income            Age     Experience  \
# count  100000.000000  1.000000e+05  100000.000000  100000.000000
# mean    50000.500000  5.001617e+06      49.995400      10.110750
# std     28867.657797  2.876394e+06      17.056051       5.996007
# min         1.000000  1.031000e+04      21.000000       0.000000
# 25%     25000.750000  2.507092e+06      35.000000       5.000000
# 50%     50000.500000  5.004938e+06      50.000000      10.000000
# 75%     75000.250000  7.477502e+06      65.000000      15.000000
# max    100000.000000  9.999180e+06      79.000000      20.000000
#
#        CURRENT_JOB_YRS  CURRENT_HOUSE_YRS      Risk_Flag
# count    100000.000000      100000.000000  100000.000000
# mean          6.342990          11.996020       0.129970
# std           3.644942           1.396826       0.336272
# min           0.000000          10.000000       0.000000
# 25%           4.000000          11.000000       0.000000
# ...

# %%
df['Risk_Flag'].value_counts()
# Out:
# Risk_Flag
# 0    87003
# 1    12997
# Name: count, dtype: int64

# %%
df1 = df[['Id', 'Income', 'Age', 'Experience', 'CURRENT_JOB_YRS', 'CURRENT_HOUSE_YRS', 'Risk_Flag']]
sns.heatmap(df1.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
df['Risk_Flag'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Risk_Flag'>

# %%
maritial_ax =df['Married/Single'].value_counts().plot(kind='bar')
maritial_ax
plt.show()

# %%
sns.countplot(data =df, x='Married/Single')
# Out:
# <Axes: xlabel='Married/Single', ylabel='count'>

# %%
sns.countplot(data=df, x='Risk_Flag')
# Out:
# <Axes: xlabel='Risk_Flag', ylabel='count'>

# %%
target_ax = sns.countplot(data=df, x='Risk_Flag')
target_ax
plt.show()

# %%
data = df.drop(columns=['CITY', 'STATE','Id'], axis=1)
data
# Out:
#         Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# 0      1303834   23           3         single          rented            no
# 1      7574516   40          10         single          rented            no
# 2      3991815   66           4        married          rented            no
# 3      6256451   41           2         single          rented           yes
# 4      5768871   47          11         single          rented            no
# ...        ...  ...         ...            ...             ...           ...
# 99995  7283454   74           5        married          rented            no
# 99996   170128   29          17         single          rented            no
# 99997  1094592   79           0         single          rented           yes
# 99998  6384060   26          14         single           owned            no
# 99999   207067   61          18         single          rented            no
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data  = df[['Married/Single','House_Ownership','Car_Ownership','Profession']]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in data.select_dtypes(include=['object']).columns:
    data.loc[:, i] = le.fit_transform(data.loc[:, i])

print(data)
# Out:
#        Married/Single House_Ownership Car_Ownership Profession
# 0                   1               2             0         33
# 1                   1               2             0         43
# 2                   0               2             0         47
# 3                   1               2             1         43
# 4                   1               2             0         11
# ...               ...             ...           ...        ...
# 99995               0               2             0         47
# 99996               1               2             0          1
# 99997               1               2             1         24
# 99998               1               1             0         48
# 99999               1               2             0          5
#
# [100000 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data=df.copy()
data = df.drop(columns=['Id', 'CITY','STATE'], axis=1)
data1 = data.copy()
for column in data1.select_dtypes(include=['object']).columns:
    data1.loc[:, column] = le.fit_transform(data1.loc[:, column])
data1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data1 = scaler.fit_transform(data1)
data1
data = pd.DataFrame(data1, columns=data.columns)
data
# Out:
#          Income       Age  Experience  Married/Single  House_Ownership  \
# 0      0.129497  0.034483        0.15             1.0              1.0
# 1      0.757263  0.327586        0.50             1.0              1.0
# 2      0.398594  0.775862        0.20             0.0              1.0
# 3      0.625310  0.344828        0.10             1.0              1.0
# 4      0.576498  0.448276        0.55             1.0              1.0
# ...         ...       ...         ...             ...              ...
# 99995  0.728125  0.913793        0.25             0.0              1.0
# 99996  0.016000  0.137931        0.85             1.0              1.0
# 99997  0.108549  1.000000        0.00             1.0              1.0
# 99998  0.638085  0.086207        0.70             1.0              0.5
# 99999  0.019698  0.689655        0.90             1.0              1.0
#
#        Car_Ownership  Profession  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  \
# ...

# %%
data = pd.DataFrame(data1, columns=data.columns)
data
# Out:
#          Income       Age  Experience  Married/Single  House_Ownership  \
# 0      0.129497  0.034483        0.15             1.0              1.0
# 1      0.757263  0.327586        0.50             1.0              1.0
# 2      0.398594  0.775862        0.20             0.0              1.0
# 3      0.625310  0.344828        0.10             1.0              1.0
# 4      0.576498  0.448276        0.55             1.0              1.0
# ...         ...       ...         ...             ...              ...
# 99995  0.728125  0.913793        0.25             0.0              1.0
# 99996  0.016000  0.137931        0.85             1.0              1.0
# 99997  0.108549  1.000000        0.00             1.0              1.0
# 99998  0.638085  0.086207        0.70             1.0              0.5
# 99999  0.019698  0.689655        0.90             1.0              1.0
#
#        Car_Ownership  Profession  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  \
# ...

# %%
data
# Out:
#          Income       Age  Experience  Married/Single  House_Ownership  \
# 0      0.129497  0.034483        0.15             1.0              1.0
# 1      0.757263  0.327586        0.50             1.0              1.0
# 2      0.398594  0.775862        0.20             0.0              1.0
# 3      0.625310  0.344828        0.10             1.0              1.0
# 4      0.576498  0.448276        0.55             1.0              1.0
# ...         ...       ...         ...             ...              ...
# 99995  0.728125  0.913793        0.25             0.0              1.0
# 99996  0.016000  0.137931        0.85             1.0              1.0
# 99997  0.108549  1.000000        0.00             1.0              1.0
# 99998  0.638085  0.086207        0.70             1.0              0.5
# 99999  0.019698  0.689655        0.90             1.0              1.0
#
#        Car_Ownership  Profession  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  \
# ...

# %%
X = data.drop('Risk_Flag', axis=1)
y = data['Risk_Flag']

# %%
y
# Out:
# 0        0.0
# 1        0.0
# 2        0.0
# 3        1.0
# 4        1.0
#         ...
# 99995    0.0
# 99996    0.0
# 99997    0.0
# 99998    0.0
# 99999    0.0
# Name: Risk_Flag, Length: 100000, dtype: float64

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
X = data.drop('Risk_Flag', axis=1)
y = data['Risk_Flag']
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
y_resampled
# Out:
# 0         0.0
# 1         0.0
# 2         0.0
# 3         1.0
# 4         1.0
#          ...
# 174001    1.0
# 174002    1.0
# 174003    1.0
# 174004    1.0
# 174005    1.0
# Name: Risk_Flag, Length: 174006, dtype: float64

# %%
from sklearn.datasets import make_classification

# %%
from collections import Counter

# %%
from sklearn.model_selection import train_test_split
X_train, X_validation, Y_train, Y_validation = train_test_split(X_resampled, y_resampled,
                                                               test_size=0.2, random_state=4)

# %%
X_train
# Out:
#           Income       Age  Experience  Married/Single  House_Ownership  \
# 17510   0.681211  0.551724        0.65             0.0              1.0
# 86912   0.332433  0.534483        0.35             1.0              0.0
# 125597  0.805209  0.362069        0.40             1.0              1.0
# 12836   0.790696  0.775862        0.00             1.0              1.0
# 172489  0.980789  0.275862        0.00             1.0              1.0
# ...          ...       ...         ...             ...              ...
# 115144  0.576498  0.448276        0.55             1.0              1.0
# 142935  0.787065  0.896552        0.80             1.0              1.0
# 129384  0.296728  0.017241        0.15             1.0              1.0
# 120705  0.976068  0.396552        0.60             1.0              0.0
# 115397  0.910945  0.586207        0.25             1.0              1.0
#
#         Car_Ownership  Profession  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS
# ...

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
Y_predict = lr.predict(X_validation)

# %%
lr.score(X_validation, Y_validation)
# Out:
# 0.5588184587092696

# %%
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score

# %%
accuracy = accuracy_score(Y_validation, Y_predict)
precision = precision_score(Y_validation, Y_predict)
recall = recall_score(Y_validation, Y_predict)
f1 = f1_score(Y_validation, Y_predict)
print("ACCURACY=", accuracy)
print("PRECESION=", accuracy)
print("RECALL=", accuracy)
print("F1_SCORE=", accuracy)
# Out:
# ACCURACY= 0.5588184587092696
# PRECESION= 0.5588184587092696
# RECALL= 0.5588184587092696
# F1_SCORE= 0.5588184587092696

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score
model = KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
Y_predict = model.predict(X_validation)

# %%
accuracy = accuracy_score(Y_validation, Y_predict)
precision = precision_score(Y_validation, Y_predict)
recall = recall_score(Y_validation, Y_predict)
f1 = f1_score(Y_validation, Y_predict)
print("ACCURACY=", accuracy)
print("PRECESION=", accuracy)
print("RECALL=", accuracy)
print("F1_SCORE=", accuracy)
# Out:
# ACCURACY= 0.9516407103040055
# PRECESION= 0.9516407103040055
# RECALL= 0.9516407103040055
# F1_SCORE= 0.9516407103040055

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
etc = ExtraTreesClassifier(random_state=42)

# %%
etc.fit(X_train, Y_train)
# Out:
# ExtraTreesClassifier(random_state=42)

# %%
Y_predict = etc.predict(X_validation)
Y_predict
# Out:
# array([1., 1., 1., ..., 1., 0., 0.])

# %%
accuracy = accuracy_score(Y_validation, Y_predict)
precision = precision_score(Y_validation, Y_predict)
recall = recall_score(Y_validation, Y_predict)
f1 = f1_score(Y_validation, Y_predict)
print("ACCURACY=", accuracy)
print("PRECESION=", accuracy)
print("RECALL=", accuracy)
print("F1_SCORE=", accuracy)
# Out:
# ACCURACY= 0.9609217861042468
# PRECESION= 0.9609217861042468
# RECALL= 0.9609217861042468
# F1_SCORE= 0.9609217861042468

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy = accuracy_score(Y_validation, Y_predict)
accuracy
# Out:
# 0.9609217861042468

# %%
cm = confusion_matrix(Y_validation, Y_predict)
cm
# Out:
# array([[16091,  1349],
#        [   11, 17351]], dtype=int64)

# %%
cr = classification_report(Y_validation, Y_predict)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.92      0.96     17440
#          1.0       0.93      1.00      0.96     17362
#
#     accuracy                           0.96     34802
#    macro avg       0.96      0.96      0.96     34802
# weighted avg       0.96      0.96      0.96     34802

# %%
sample_data = pd.DataFrame([[0.576498,0.448276,0.55,1.0,1.0,0.0,0.22,0.214286,1.00]],
                        columns=['Income', 'Age', 'Experience', 'Married/Single', 'House_Ownership', 'Car_Ownership', 'Profession', 'CURRENT_JOB_YRS', 'CURRENT_HOUSE_YRS'])

# %%
sample_data
# Out:
#      Income       Age  Experience  Married/Single  House_Ownership  \
# 0  0.576498  0.448276        0.55             1.0              1.0
#
#    Car_Ownership  Profession  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS
# 0            0.0        0.22         0.214286                1.0

# %%
prediction = etc.predict(sample_data)
prediction
# Out:
# array([1.])
